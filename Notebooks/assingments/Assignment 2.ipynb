# %% [markdown]
# # Assignment 2 - Exercise on RDF and RDFS
#
# ## Introduction
#
# ### Important dates
#  + Homework release: Monday, 1st October 2019
#  + Homework due: Wednesday, 16th October 2019 (23:59 hours, 11:59 PM)
#  + Peer review: Friday, 18th October 2019 (23:59 hours, 11:59 PM)
#  + Grading release: Wednesday, 30th October 2019
#
# ### Objective
#  * Get used to the different syntaxes of RDF.
#
# ### Tasks
#  * Take the text of an RDF file and create its corresponding graph
#  * Take an RDF graph and create its corresponding RDF/XML and Turtle files
#     * _Note: you can use http://rdf.greggkellogg.net/distiller to check them_
#
# ### Description
#
# **Exercise on RDF and RDFS**.
#
# Assignment 2 consist of three tasks. Exercise 1.a, which will be an image. Exercise 1.b.a in RDF/XML. Exercise 1.b.b in Turtle.
#
# For the solution, update this notebook in your Github repository. After first submision, search for one of your colleages repository, check his assigment and make the appropiate comments for the peer review work. Finally, submit the additional work with a new update of this notebook.
#
# > For example, with the first sync of the template repository I would start working on this assigment. Once homework are done (and before homework due date) I would make a new sync to the repo and create millestone _Assigment_2.1_ within it. Then, I would continue working on the peer review and when finished I would create a second millestone, _Assigment_2.2_.
# In case you need to correct anything of your submission, before millestone due date, edit the millestone and upload your new book.
#
# ***

# %% [markdown]
# ## Exercise 1.a)
#
# Create a graph from a file
# -----
#
# ### Description
#
# In this exercise you will have to create a graph from a selected file.
#
# File (.rdf) will be available at:
# https://delicias.dia.fi.upm.es/nextcloud/index.php/s/FBqEsMfTR4nWpro
#
#
# After submission is done, during the _peer review period_ compare your graph with those of your colleagues and leave some notes, including the following:
#  * Which aproach is better and why
#  * If any error detected in your colleage one or in yours, comment why you think that result was obteined
#  * After comparing both give a grade to both solutions
#
# ### File to be converted
#
# File is available in the following lines:
#
#
# <details>
#     <summary>
#         View file
#     </summary>
# <p>
#
# ```XML
# <?xml version="1.0"?>
#
# <rdf:RDF
# xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
# xmlns:cd="http://www.recshop.fake/cd#">
#
# <rdf:Description
# rdf:about="http://www.recshop.fake/cd/Empire Burlesque">
#   <cd:artist>Bob Dylan</cd:artist>
#   <cd:country>USA</cd:country>
#   <cd:company>Columbia</cd:company>
#   <cd:price>10.90</cd:price>
#   <cd:year>1985</cd:year>
# </rdf:Description>
#
# <rdf:Description
# rdf:about="http://www.recshop.fake/cd/Hide your heart">
#   <cd:artist>Bonnie Tyler</cd:artist>
#   <cd:country>UK</cd:country>
#   <cd:company>CBS Records</cd:company>
#   <cd:price>9.90</cd:price>
#   <cd:year>1988</cd:year>
# </rdf:Description>
# .
# .
# .
# </rdf:RDF>
# ```
#
#
# </p>
# </details>
#
# Or at:
#  *  https://delicias.dia.fi.upm.es/nextcloud/index.php/s/FBqEsMfTR4nWpro

# %% [markdown]
# ### Solution

# %% [markdown]
# Place your solution here:

# %% [markdown]
# <span style="color:red">Work here</span>
#
#  > _placeYourImage_
#
#  > Ex:
#  ![image.png](attachment:image.png)

# %% [markdown]
# #### Explanation
#
# In no more than five lines, explain how you got this result.

# %% [markdown]
# #### Peer Review
#
# After first submission is done, you will have to do peer review with an assigment from the colleage you choose.
#
# Compare your graphs and leave your comments down below.

# %% [markdown]
# Your comments on the peer review:
#
# > _Wait until peer review period_
#
# <span style="color:red">Work here</span>

# %% [markdown]
# Grade your work:
#
#  > _Wait until peer review period_
#
#  <span style="color:red">Work here</span>
#
#  * Grade for your work: `grade`
#  * Grade for your colleage work: `grade`

# %% [markdown]
# ## Exercise 1.b)
#
# Create a file from a graph
# -----
#
# ### Description
#
# In this exercise you will have to create two files from a selected graph.
#
# The graph to be converted is the following:
# ![image.png](attachment:image.png)
#
# In this exercise you will have to provide two conversions from the image.
# 1. Exercise 1.b.a), transforming into the RDF/XML syntax.
# 2. Exercise 1.b.b), transforming into the Turtle syntax.

# %% [markdown]
# ### Exercise 1.b.a)
#
# #### Description
#
# As explained above, in this exercise you will have to convert the graph to the RDF/XML syntax. Write the resulted code in the blocks below.
#
#
# #### Solution
#
#
# Place your solution here:

# %% [markdown]
# <span style="color:red">Work here</span>
#
# ```XML
# yourXMLCodeHere
# ```

# %% [markdown]
# #### Explanation
#
# In no more than three lines, explain how you got this result.

# %% [markdown]
# <span style="color:red">Work here</span>
#
# _Explain your results_

# %% [markdown]
# ### Exercise 1.b.b)
#
# #### Description
#
# As explained above, in this exercise you will have to convert the graph to the Turtle syntax.
#
#
# #### Solution
#
#
# Place your solution here:
#
# <span style="color:red">Work here</span>
#
# ```Turtle
#     yourTurtleCodeHere
# ```

# %% [markdown]
# #### Explanation
#
# In no more than three lines, explain how you got this result.

# %% [markdown]
# <span style="color:red">Work here</span>
#
# _Explain your results_
