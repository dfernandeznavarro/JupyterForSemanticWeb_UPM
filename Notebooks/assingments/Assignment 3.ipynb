# %% [markdown]
# # Assignment 3 - Exercise on SPARQL
#
# ## Introduction
#
# ### Important dates
#  + Homework release: Monday, 1st October 2019
#  + Homework due: Wednesday, 16th October 2019 (23:59 hours, 11:59 PM)
#  + Peer review: Friday, 18th October 2019 (23:59 hours, 11:59 PM)
#  + Grading release: Wednesday, 30th October 2019
#
# ### Objective
#  * Understand how to perform SPARQL queries.
#  * Understand how to perform more complex SPARQL queries
#
# ### Tasks
#  * Perform a set of SPARQL queries over a given ontology
#
# ### Description
#
# **Exercise on SPARQL**.
#
# Assignment 3 consist of two tasks. Exercise 1, where you will query a sample ontology. Exercise 2, querying over DBpedia.
#
# _For the solution, update this notebook in your Github repository. After first submision, search for one of your colleages repository, check his assigment and make the appropiate comments for the peer review work. Finally, submit the additional work with a new update of this notebook._
#
# _> For example, with the first sync of the template repository I would start working on this assigment. Once homework are done (and before homework due date) I would make a new sync to the repo and create millestone _Assigment_2.1_ within it. Then, I would continue working on the peer review and when finished I would create a second millestone, _Assigment_2.2_.
# In case you need to correct anything of your submission, before millestone due date, edit the millestone and upload your new book.
#
# ***

# %% [markdown]
# ## Exercise 1
#
# Querying over a sample ontology
# -----
#
# ### Description
#
# In this exercise you will have to create queries to answer some questions about the given model. In SPARQL language query the model and place your solution here. The queries to be done are placed in the [queries section](#Sample-model-queries).
#
# ### Sample model
#
# ![image.png](attachment:image.png)
#
# ### Sample model queries
#
# 1. [Get all the classes](#GetAllTheClasses)
# 1. [Get the subclasses of the class Establishment](#GetSubclassesOfEstablishment)
# 1. [Get the instances of the class City](#GetInstancesOfCity)
# 1. [Get the number of inhabitants of Santiago de Compostela](#GetInstancesOfInhabitantsOfSantiago)
# 1. [Get the number of inhabitants of Santiago de Compostela and of Arzua]
# 1. [Get different places with the inhabitants number, ordering the results by name of the place (ascending)]
# 1. [Get all the instances of Locality with their inhabitant number (if it exists)]
# 1. [Get all the places with more than 200.000 inhabitants]
# 1. [Get postal data of Pazo_Breogan (street, number, locality, province)]
# 1. [Get the subclasses of class Location]
# 1. [Get the instances of class Locality]
# 1. [Describe the resource with rdfs:label "Madrid"]
# 1. [Construct the RDF(S) graph that directly relates all the touristic places with their respective provinces, using a new property called ”isIn”]
# 1. [Ask if there is some instance of Town]
# 1. [Ask if there is some instance of Chapel]

# %% [markdown]
# ### Solution

# %% [markdown]
# Place your solutions in the following blocks.

# %% [markdown]
# #### Get all the classes<a id='GetAllTheClasses'></a>

# %% [markdown]
# <span style="color:red">Work here</span>
#
# ```sparql
# yourSPARQLCodeHere
# ```

# %% [markdown]
# #### Get the subclasses of the class Establishment <a id='GetSubclassesOfEstablishment'></a>

# %% [markdown]
# <span style="color:red">Work here</span>
#
# ```sparql
# yourSPARQLCodeHere
# ```

# %% [markdown]
# #### Query - Get the instances of the class City <a id='GetInstancesOfCity'></a>

# %% [markdown]
# <span style="color:red">Work here</span>
#
# ```sparql
# yourSPARQLCodeHere
# ```

# %% [markdown]
# #### Query - Get the number of inhabitants of Santiago de Compostela <a id='GetInstancesOfInhabitantsOfSantiago'></a>

# %% [markdown]
# <span style="color:red">Work here</span>
#
# ```sparql
#     yourSPARQLCodeHere
#
# ```

# %% [markdown]
# ## Exercise 2
#
# Querying over DBpedia
# -----
#
# ### Description
#
# In this exercise you will have to create and perform more complex queries over DBpedia to answer the questions given below from the [queries section](#DBpedia-Queries).
#
# DBpedia can be queried at http://dbpedia.org/snorql/.
#
# ### DBpedia Queries
#
# 1. [Get all the properties that can be applied to instances of
# the Politician class (<http://dbpedia.org/ontology/Politician>)](#GetAllPoliticianProperties)
# 1. [Get all the properties, except rdf:type, that can be applied to instances of the Politician class](#GetAllPoliticianProperties_2)
# 1. [Which different values exist for the properties, except rdf:type, of the instances of the Politician class?](#GetInstancesOfPolitician)
# 1. [For each of the properties, except rdf:type, that can be applied to instances of the Politician class, which different values do they take in those instances?](#GetDiffValuesForPoliticiansInstances)
# 1. [For each of the properties, except rdf:type, that can be applied to instances of the Politician class, how many distinct values do they take in those instances?](#GetDistinctValuesForPoliticiansInstances)

# %% [markdown]
# ### Solution

# %% [markdown]
# Place your solutions in the following blocks.

# %% [markdown]
# #### Get all the properties that can be applied to instances of the Politician class<a id='GetAllPoliticianProperties'></a>

# %% [markdown]
# <span style="color:red">Work here</span>
#
# ```sparql
# yourSPARQLCodeHere
# ```

# %% [markdown]
# #### Get all the properties, except rdf:type, that can be applied to instances of the Politician class<a id='GetAllPoliticianProperties_2'></a>

# %% [markdown]
# <span style="color:red">Work here</span>
#
#
# ```sparql
# yourSPARQLCodeHere
# ```

# %% [markdown]
# #### Which different values exist for the properties, except rdf:type, of the instances of the Politician class?<a id='GetInstancesOfPolitician'></a>

# %% [markdown]
# <span style="color:red">Work here</span>
#
# ```sparql
# yourSPARQLCodeHere
# ```

# %% [markdown]
# #### For each of the properties, except rdf:type, that can be applied to instances of the Politician class, which different values do they take in those instances?<a id='GetDiffValuesForPoliticiansInstances'></a>

# %% [markdown]
# <span style="color:red">Work here</span>
#
# ```sparql
# yourSPARQLCodeHere
# ```

# %% [markdown]
# #### For each of the properties, except rdf:type, that can be applied to instances of the Politician class, how many distinct values do they take in those instances?<a id='GetDistinctValuesForPoliticiansInstances'></a>

# %% [markdown]
# <span style="color:red">Work here</span>
#
# ```sparql
# yourSPARQLCodeHere
# ```
